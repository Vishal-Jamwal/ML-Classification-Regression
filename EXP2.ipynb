# %%
import pandas as pd
import numpy as np
# Creating empty series
ser = pd.Series(dtype='object')
print("Pandas Series: ", ser)
# simple dictionary
data={1:'s', 2:'e', 3:'r', 4:'i', 5:'e', 6:'s'}
ser=pd.Series(data)
print("Pandas Series:\n", ser)
# Out:
# Pandas Series:  Series([], dtype: object)
# Pandas Series:
#  1    s
# 2    e
# 3    r
# 4    i
# 5    e
# 6    s
# dtype: object

# %%
#series using scalar values
import pandas as pd
import numpy as np
# Creating empty series
ser = pd.Series(dtype='object')
print("Pandas Series: ", ser)
ser=pd.Series(4, index=[1,2,3,4])
print("Pandas Series:\n", ser)
# Out:
# Pandas Series:  Series([], dtype: object)
# Pandas Series:
#  1    4
# 2    4
# 3    4
# 4    4
# dtype: int64

# %%
x=pd.Series([1,2,3],index=['a','b','c'])
print(x.shape)
print(x.size)
print(x.index)
print(x.ndim)
print(x.values)
print(x.dtypes)
print(x.nbytes)
print(x.empty)
print(x.hasnans)
# Out:
# (3,)
# 3
# Index(['a', 'b', 'c'], dtype='object')
# 1
# [1 2 3]
# int64
# 24
# False
# False

# %%
x=pd.Series([1,2,3],index=['a','b','c'])
x
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
# importing the module
import pandas as pd
# creating a sample dataframe
data = pd.DataFrame({'Brand': ['Maruti', 'Hyundai', 'Tata',
'Mahindra', 'Maruti', 'Hyundai',
'Renault', 'Tata', 'Maruti'],
'Year': [2012, 2014, 2011, 2015, 2012,
2016, 2014, 2018, 2019],
'Kms Driven': [50000, 30000, 60000,
25000, 10000, 46000,
31000, 15000, 12000],
'City': ['Gurgaon', 'Delhi', 'Mumbai',
'Delhi', 'Mumbai', 'Delhi',
'Mumbai', 'Chennai', 'Ghaziabad'],

'Mileage': [28, 27, 25, 26, 28,
29, 24, 21, 24]})

# displaying the DataFrame
display(data)
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1   Hyundai  2014       30000      Delhi       27
# 2      Tata  2011       60000     Mumbai       25
# 3  Mahindra  2015       25000      Delhi       26
# 4    Maruti  2012       10000     Mumbai       28
# 5   Hyundai  2016       46000      Delhi       29
# 6   Renault  2014       31000     Mumbai       24
# 7      Tata  2018       15000    Chennai       21
# 8    Maruti  2019       12000  Ghaziabad       24

# %%
#Display the first row
data.loc[2]
# Out:
# Brand           Tata
# Year            2011
# Kms Driven     60000
# City          Mumbai
# Mileage           25
# Name: 2, dtype: object

# %%
#Display Brand of first row
data.loc[2,'Year']
# Out:
# np.int64(2011)

# %%
#Display 1st, 2nd and 5th rows
data.loc[[0,1,4]]
# Out:
#      Brand  Year  Kms Driven     City  Mileage
# 0   Maruti  2012       50000  Gurgaon       28
# 1  Hyundai  2014       30000    Delhi       27
# 4   Maruti  2012       10000   Mumbai       28

# %%
#Display City of 1st and 2nd row
data.loc[[0,1],'City']
# Out:
# 0    Gurgaon
# 1      Delhi
# Name: City, dtype: object

# %%
#Display 2nd row to 6th row
data.loc[1:5]
# Out:
#       Brand  Year  Kms Driven    City  Mileage
# 1   Hyundai  2014       30000   Delhi       27
# 2      Tata  2011       60000  Mumbai       25
# 3  Mahindra  2015       25000   Delhi       26
# 4    Maruti  2012       10000  Mumbai       28
# 5   Hyundai  2016       46000   Delhi       29

# %%
#Display 2nd row to 6th row
data.loc[1:5]
# Out:
#       Brand  Year  Kms Driven    City  Mileage
# 1   Hyundai  2014       30000   Delhi       27
# 2      Tata  2011       60000  Mumbai       25
# 3  Mahindra  2015       25000   Delhi       26
# 4    Maruti  2012       10000  Mumbai       28
# 5   Hyundai  2016       46000   Delhi       29

# %%
# Select first and third rows by position
rows = data.iloc[[0, 2]]
rows
# Out:
#     Brand  Year  Kms Driven     City  Mileage
# 0  Maruti  2012       50000  Gurgaon       28
# 2    Tata  2011       60000   Mumbai       25

# %%
#Select first and 3rd rows (Second column value only)
d=data.iloc[[0,2],[1]]
d
# Out:
#    Year
# 0  2012
# 2  2011

# %%
import pandas as pd
data = {
"calories": [420, 380, 390],
"duration": [50, 40, 45]
}
df = pd.DataFrame(data, index = ["day1", "day2", "day3"])
df
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
import pandas as pd
df=pd.read_csv("Iris_data_sample.csv")
df
# Out:
#      Unnamed: 0 SepalLengthCm  SepalWidthCm PetalLengthCm  PetalWidthCm  \
# 0             1           5.1           3.5           1.4           0.2
# 1             2           4.9           NaN           1.4           0.2
# 2             3           4.7           3.2           1.3           0.2
# 3             4            ??           3.1           1.5           0.2
# 4             5             5           3.6           ###           0.2
# ..          ...           ...           ...           ...           ...
# 145         146           6.7           3.0           5.2           2.3
# 146         147           6.3           2.5             5           1.9
# 147         148           6.5           3.0           5.2           2.0
# 148         149           6.2           3.4           5.4           2.3
# 149         150           5.9           3.0           5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1               NaN
# 2       Iris-setosa
# ...

# %%
import pandas as pd
df=pd.read_csv("Iris_data_sample.csv",index_col=0)
df
# Out:
#     SepalLengthCm  SepalWidthCm PetalLengthCm  PetalWidthCm         Species
# 1             5.1           3.5           1.4           0.2     Iris-setosa
# 2             4.9           NaN           1.4           0.2             NaN
# 3             4.7           3.2           1.3           0.2     Iris-setosa
# 4              ??           3.1           1.5           0.2     Iris-setosa
# 5               5           3.6           ###           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 146           6.7           3.0           5.2           2.3  Iris-virginica
# 147           6.3           2.5             5           1.9  Iris-virginica
# 148           6.5           3.0           5.2           2.0  Iris-virginica
# 149           6.2           3.4           5.4           2.3  Iris-virginica
# 150           5.9           3.0           5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#Junk values can be converted to missing values by passing them as a list to the parameter ‘n
import pandas as pd
df=pd.read_csv("Titanic-Dataset.csv",index_col=0,na_values=['??','###'])
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
print("Name:Vishal Jamwal Roll no: 2330278");
# Out:
# Name:Vishal Jamwal Roll no: 2330278

# %%
df.isnull()
# Out:
#              Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# PassengerId
# 1               False   False  False  False  False  False  False   False
# 2               False   False  False  False  False  False  False   False
# 3               False   False  False  False  False  False  False   False
# 4               False   False  False  False  False  False  False   False
# 5               False   False  False  False  False  False  False   False
# ...               ...     ...    ...    ...    ...    ...    ...     ...
# 887             False   False  False  False  False  False  False   False
# 888             False   False  False  False  False  False  False   False
# 889             False   False  False  False   True  False  False   False
# 890             False   False  False  False  False  False  False   False
# 891             False   False  False  False  False  False  False   False
#
#               Fare  Cabin  Embarked
# PassengerId
# ...

# %%
df.notnull()
# Out:
#              Survived  Pclass  Name   Sex    Age  SibSp  Parch  Ticket  Fare  \
# PassengerId
# 1                True    True  True  True   True   True   True    True  True
# 2                True    True  True  True   True   True   True    True  True
# 3                True    True  True  True   True   True   True    True  True
# 4                True    True  True  True   True   True   True    True  True
# 5                True    True  True  True   True   True   True    True  True
# ...               ...     ...   ...   ...    ...    ...    ...     ...   ...
# 887              True    True  True  True   True   True   True    True  True
# 888              True    True  True  True   True   True   True    True  True
# 889              True    True  True  True  False   True   True    True  True
# 890              True    True  True  True   True   True   True    True  True
# 891              True    True  True  True   True   True   True    True  True
#
#              Cabin  Embarked
# ...

# %%
df1=df.fillna(0)
df1
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df2=df.ffill()
df2
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df3=df.bfill()
df3
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df4=df.dropna()
df4
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(df4['Age'], color='red',edgecolor='white',bins=5)
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import matplotlib.pyplot as plt
plt.hist(df4['Fare'], color='orange',edgecolor='white',bins=5)
plt.title('Histogram of Fare')
plt.xlabel('Fare')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import matplotlib.pyplot as plt
plt.hist(df4['SibSp'], color='red',edgecolor='white',bins=5)
plt.title('Histogram of SibSp')
plt.xlabel('SibSp')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import matplotlib.pyplot as plt
plt.hist(df4['Parch'], color='pink',edgecolor='white',bins=5)
plt.title('Histogram of Parch')
plt.xlabel('Parch')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import matplotlib.pyplot as plt
plt.hist(df4['Pclass'], color='grey',edgecolor='white',bins=3) # Pclass has 3 categories
plt.title('Histogram of Pclass')
plt.xlabel('Pclass')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import seaborn as sns
sns.set()
sns.scatterplot(x='Age',y='Fare',data=df4)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(x='Fare',y='Age',data=df4)
# Out:
# <Axes: xlabel='Fare', ylabel='Age'>

# %%
sns.scatterplot(x='Age',y='Fare',data=df4)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(x='SibSp',y='Parch',data=df4)
# Out:
# <Axes: xlabel='SibSp', ylabel='Parch'>

# %%
sns.scatterplot(x='Parch',y='Fare',data=df4)
# Out:
# <Axes: xlabel='Parch', ylabel='Fare'>

# %%
sns.scatterplot(x='SibSp',y='Age',data=df4)
# Out:
# <Axes: xlabel='SibSp', ylabel='Age'>

# %%
sns.heatmap(data=df4[['Age','Fare','SibSp','Parch']].corr(),
annot=True, linecolor='white', linewidths=0.25, cbar=True)
# Out:
# <Axes: >

# %%
print("Name: Vishal, Roll no: 2330278")
# Out:
# Name: Vishal, Roll no: 2330278
